# %% [markdown]
# # Customer Churn Prediction for E-Commerce
#
# IBM SkillsBuild Data Analytics with AI Internship Project
#
# **Student:** Subahan Raphikso Tamboli
#
# Run the cell below in Google Colab. It downloads and runs the project code from this GitHub repository.

# %%
# !wget -q https://raw.githubusercontent.com/subahantamboli134-lab/customer-churn-prediction-ecommerce/main/customer_churn_project.py -O customer_churn_project.py
# %run customer_churn_project.py
